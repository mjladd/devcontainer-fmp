# %% [markdown]
# <div>
# <a href="http://www.music-processing.de/"><img style="float:left;" src="../data/FMP_Teaser_Cover.png" width=40% alt="FMP"></a>
# <a href="https://www.audiolabs-erlangen.de"><img src="../data/Logo_AudioLabs_Long.png" width=59% style="float: right;" alt="AudioLabs"></a>
# </div>

# %% [markdown]
# <div>
# <a href="../B/B.html"><img src="../data/B_nav.png" width="100"  style="float:right;" alt="B"></a>
# <h1> Basics</h1>
# </div>
#
# <br/>
#
# <p>
# The notebooks of <strong>Part B</strong> serve different purposes. First, these notebooks describe the main tools used for developing the FMP notebooks. Second, they give short introductions of the relevant technical concepts while providing links to more detailed tutorials. Third, the notebooks give examples for best practices for generating and using code, figures, and sound elements.
# </p>
#
# <div class="alert alert-block alert-warning">
# <strong>Note:</strong> The notebooks of the Part B do not have to be read in the order they are specified. The B-part notebooks serve as a documentation and reference of overarching aspects that concern the FMP notebooks of the subsequent parts.
# <br>
# </div>

# %% [markdown]
# ## Overview
#
#
#
# <table class="table table-hover" style="border:none; font-size: 90%; width:100%; text-align:left">
# <colgroup>
#     <col span="1" style="width:30%; text-align:left">
#     <col span="1" style="width:50%; text-align:left">
#     <col span="1" style="width:10%; text-align:left">
#     <col span="1" style="width:10%; text-align:left">
# </colgroup>
# <tr text-align="left" style="border:1px solid #C8C8C8; background-color:#F0F0F0" >
#     <td style="border:none; text-align:left"><b>Topic</b></td>
#     <td style="border:none; text-align:left"><b>Description</b></td>
#     <td style="border:none; text-align:left"><b>HTML</b></td>
#     <td style="border:none; text-align:left"><b>IPYNB</b></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_GetStarted.html">Get Started</a></td>
#     <td style="border:none; text-align:left">Explanation on how to install and use the FMP notebooks</td>
#     <td style="border:none; text-align:left"><a href="../B/B_GetStarted.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_GetStarted.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_Installation.html">Installation</a></td>
#     <td style="border:none; text-align:left">Installation of Python (as specified in <code>environment.yml</code>) using Conda</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Installation.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Installation.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_Jupyter.html">Jupyter Notebook</a></td>
#     <td style="border:none; text-align:left">Usage of Jupyter notebook framework</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Jupyter.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Jupyter.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_PythonBasics.html">Python Basics</a></td>
#     <td style="border:none; text-align:left">Introduction of basic data types, control structures, and functions</td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonBasics.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonBasics.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_PythonStyleGuide.html">Python Style Guide</a></td>
#     <td style="border:none; text-align:left">Recommendations for programming style</td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonStyleGuide.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonStyleGuide.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_Multimedia.html">Multimedia</a></td>
#     <td style="border:none; text-align:left">Integration of multimedia objects (images, audio, video files) into notebooks</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Multimedia.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Multimedia.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_PythonVisualization.html">Python Visualization</a></td>
#     <td style="border:none; text-align:left">Generation of figures and images</td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonVisualization.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonVisualization.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_PythonAudio.html">Python Audio</a></td>
#     <td style="border:none; text-align:left">Reading and writing audio files</td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonAudio.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonAudio.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_PythonNumba.html">Numba</a></td>
#     <td style="border:none; text-align:left">Acceleration of Python functions via JIT compilation</td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonNumba.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_PythonNumba.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_Annotations.html">Annotation Visualization</a></td>
#     <td style="border:none; text-align:left">Visualization of annotations (single value, segments)</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Annotations.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Annotations.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_Sonification.html">Sonification</a></td>
#     <td style="border:none; text-align:left">Sonification methods for time positions, F0 trajectories, and chromagrams</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Sonification.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Sonification.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_libfmp.html">libfmp</a></td>
#     <td style="border:none; text-align:left">Library of FMP-specific Python functions</td>
#     <td style="border:none; text-align:left"><a href="../B/B_libfmp.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_libfmp.ipynb">[ipynb]</a></td>
# </tr>
#
# <tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left"><a href="../B/B_ResourcesMIR.html">MIR Resources</a></td>
#     <td style="border:none; text-align:left">Links to resources that are useful for MIR</td>
#     <td style="border:none; text-align:left"><a href="../B/B_ResourcesMIR.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_ResourcesMIR.ipynb">[ipynb]</a></td>
# </tr>
# <!--<tr text-align="left" style="border:1px solid #C8C8C8">
#     <td style="border:none; text-align:left">Git<a href="../B/B_Git.html">Git</a></td>
#     <td style="border:none; text-align:left">Introduction of the version control system Git</td>
#     <td style="border:none; text-align:left"><a href="../B/B_Git.html">[html]</a></td>
#     <td style="border:none; text-align:left"><a href="../B/B_Git.ipynb">[ipynb]</a></td>
# </tr>-->
# </table>

# %% [markdown]
# <table style="border:none">
# <tr style="border:none">
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C0/C0.html"><img src="../data/C0_nav.png" style="height:50px" alt="C0"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C1/C1.html"><img src="../data/C1_nav.png" style="height:50px" alt="C1"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C2/C2.html"><img src="../data/C2_nav.png" style="height:50px" alt="C2"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C3/C3.html"><img src="../data/C3_nav.png" style="height:50px" alt="C3"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C4/C4.html"><img src="../data/C4_nav.png" style="height:50px" alt="C4"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C5/C5.html"><img src="../data/C5_nav.png" style="height:50px" alt="C5"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C6/C6.html"><img src="../data/C6_nav.png" style="height:50px" alt="C6"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C7/C7.html"><img src="../data/C7_nav.png" style="height:50px" alt="C7"></a></td>
#     <td style="min-width:50px; border:none" bgcolor="white"><a href="../C8/C8.html"><img src="../data/C8_nav.png" style="height:50px" alt="C8"></a></td>
# </tr>
# </table>
